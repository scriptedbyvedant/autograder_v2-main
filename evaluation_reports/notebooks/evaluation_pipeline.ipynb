# %% [markdown]
# # Evaluation Pipeline Notebook
#
# This notebook mirrors the CLI reproduction steps described in the thesis and README. Execute the cells in order to generate the raw csv exports, sanitise them, rebuild the figures, and recompute the reported metrics.

# %%
# %run ../generate_raw_data.py

# %%
# %run ../export_datasets.py

# %%
# %run ../generate_figures.py

# %%
# %run ../run_quality_checks.py
